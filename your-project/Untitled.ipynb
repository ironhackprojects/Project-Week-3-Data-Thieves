# %%
import pandas as pd

# %%
data = pd.read_csv('All_Cars_Cleaned.csv')
# Out:
#        Unnamed: 0  Ano de Registo Combustível Condição          ID  \
# 0               0            2013    Gasolina   Usados  8073675579
# 1               1            2012      Diesel   Usados  8069978966
# 2               2            2013      Diesel   Usados  8068316065
# 3               3            2018      Diesel   Usados  8074629399
# 4               4            2018      Diesel   Usados  8075510964
# ...           ...             ...         ...      ...         ...
# 15809       15809            2017      Diesel   Usados  8047877369
# 15810       15810            2015    Gasolina   Usados  8075644442
# 15811       15811            2018      Diesel   Usados  8074969766
# 15812       15812            2018      Diesel   Usados  8041049841
# 15813       15813            2018      Diesel   Usados  8070351518
#
#                Marca  Potência  Quilómetros    Segmento Tipo de Caixa  \
# 0           Cadillac       409        47200    SUV / TT    Automática
# ...

# %%
german_data = pd.read_csv('../datasets/german_transl.csv')
german_data.head()
# Out:
#    Unnamed: 0                                               name  price  \
# 0           3                                 GOLF_4_1_4__3TÜRER   1500
# 1           4                     Skoda_Fabia_1.4_TDI_PD_Classic   3600
# 2           6                        Peugeot_206_CC_110_Platinum   2200
# 3          10                                  Mazda_3_1.6_Sport   2000
# 4          14  Nissan_Navara_2.5DPF_SE4x4_Klima_Sitzheizg_Blu...  17999
#
#        vehicle_type  year transmission  horsepower    model      km fuel_type  \
# 0         small_car  2001       manual          73     golf  150000       gas
# 1         small_car  2008       manual          68    fabia   90000    diesel
# 2            cabrio  2004       manual         107  2_reihe  150000       gas
# 3  large_family_car  2004       manual         103  3_reihe  150000       gas
# 4               suv  2011       manual         187   navara   70000    diesel
#
#         brand notRepairedDamage
# ...

# %%
set(german_data['fuel_type'])
# Out:
# {'CNG', 'GPL', 'diesel', 'gas', 'hybrid', nan, 'other'}

# %%
german_data['fuel_type'].isnull().sum()
# Out:
# 47

# %%
base_data = pd.read_csv('base_data.csv')
base_data.head()
# Out:
#    Unnamed: 0           0                                                  1  \
# 0           0  8059436495  https://www.standvirtual.com/anuncio/vw-golf-v...
# 1           1  8065634238  https://www.standvirtual.com/anuncio/bmw-320-3...
# 2           2  8074898322  https://www.standvirtual.com/anuncio/mercedes-...
# 3           3  8074081544  https://www.standvirtual.com/anuncio/peugeot-2...
# 4           4  8072669177  https://www.standvirtual.com/anuncio/honda-hr-...
#
#                                     2      3
# 0                           VW Golf V  7 500
# 1     BMW 320 320 D Pack M - Nacional  7 500
# 2        Mercedes-Benz E 220 Elegance  7 500
# 3  Peugeot 208 1.2 PureTech Signature  7 500
# 4     Honda HR-V 1.5 i-VTEC EXECUTIVE  7 500

# %%
price = base_data[['0','3']]
price.head()
price.to_csv('sv_prices.csv')

# %%
group_by

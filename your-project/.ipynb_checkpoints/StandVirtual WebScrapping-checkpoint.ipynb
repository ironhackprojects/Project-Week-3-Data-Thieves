# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www.standvirtual.com/carros/?search%5Border%5D=created_at%3Adesc'

html = requests.get(url).content
soup = BeautifulSoup(html, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <link href="//carspt-statics.akamaized.net" rel="dns-prefetch"/>
# <link href="//carspt-images.akamaized.net" rel="dns-prefetch"/>
# <link href="//tpc.googlesyndication.com" rel="dns-prefetch"/>
# <link href="//apis.google.com" rel="dns-prefetch"/>
# <link href="//pagead2.googlesyndication.com" rel="dns-prefetch"/>
# <link href="//securepubads.g.doubleclick.net" rel="dns-prefetch"/>
# <link href="//dis.criteo.com" rel="dns-prefetch"/>
# <link href="//api.mixpanel.com" rel="dns-prefetch"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# ...

# %%
#cars = soup.find_all('h2', attrs = {'class': 'offer-title ds-title'})
#cars[1].text.replace('\n','').strip()
link = soup.find_all('a', attrs = {'class': 'offer-title__link'})
link[1]['href'] # gets the link to the add
link[1]['data-ad-id'] # gets the add reference (i.e index)
link[1]['title']
# Out:
# 'VW Tiguan 1.4 TSi Sport 4Motion'

# %%
for x in range(500): 
    url.join(str(x))

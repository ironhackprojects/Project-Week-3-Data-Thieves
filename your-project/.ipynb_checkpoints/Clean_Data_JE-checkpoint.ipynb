# %%
import pandas as pd
import numpy as np
import re

# %%
# Load scrapped CSV files

data1 = pd.read_csv('SV1663.csv')
data2 = pd.read_csv('SV2942.csv')
data3 = pd.read_csv('SV5092.csv')
data4 = pd.read_csv('SV6176.csv')
data5 = pd.read_csv('SV7401.csv')
data6 = pd.read_csv('SV13537.csv')
data7 = pd.read_csv('StdV499.csv')

# %%
#concatenate all df
#data = data7
data = pd.concat([data1, data2, data3, data4, data5, data6, data7])
data.shape
# Out:
# (31989, 15)

# %%
# Clean data

# Drop not used columns
data.reset_index(inplace = True)
data.drop(['Classe do veículo', 'Valor Fixo', 'Matrícula', 'Unnamed: 0','index'], axis = 1, inplace = True)

# Drop New Cars and public transport bus (1 vehicle)
data = data [data['Condição'] == 'Usados']
data = data [data['Segmento'] != 'Transportes']

# Column Potência convert to int
data['Potência'] = [re.sub('\D+','', str(el)) for el in data['Potência']]
data['Potência'] = data['Potência'].astype(int)
data = data[data['Potência'] > 10]

# Column km convert to int & remove very low values not compatible with used cars
data['Quilómetros'] = [int(re.sub('\D+','', el)) for el in data['Quilómetros']]
data = data[data['Quilómetros'] > 100]
data.shape

#NaN filling
data['Tipo de Caixa'].fillna('Unknown', inplace = True)

#drop duplicate entries
data.drop_duplicates(inplace = True)
duplicated_IDs = [8074761416,8073913822,8072480648,8075710174,8074971964,8075744290]
data.drop([442, 29824, 1911,2010,3690,4261],axis = 0, inplace = True)
data.reset_index(inplace = True)
data.drop(['index'], axis = 1, inplace = True)

# %%
data.to_csv('Final300.csv')
data
# Out:
#        Ano de Registo Combustível Condição          ID          Marca  \
# 0                2013    Gasolina   Usados  8073675579       Cadillac
# 1                2012      Diesel   Usados  8069978966        Porsche
# 2                2013      Diesel   Usados  8068316065        Citroën
# 3                2018      Diesel   Usados  8074629399            BMW
# 4                2018      Diesel   Usados  8075510964  Mercedes-Benz
# ...               ...         ...      ...         ...            ...
# 15809            2017      Diesel   Usados  8047877369           MINI
# 15810            2015    Gasolina   Usados  8075644442         Yamaha
# 15811            2018      Diesel   Usados  8074969766            BMW
# 15812            2018      Diesel   Usados  8041049841            BMW
# 15813            2018      Diesel   Usados  8070351518  Mercedes-Benz
#
#        Potência  Quilómetros    Segmento Tipo de Caixa     Série    Origem
# 0           409        47200    SUV / TT    Automática       NaN       NaN
# 1           250       113000       Sedan    Automática       NaN       NaN
# 2           115       104000    Citadino        Manual       NaN       NaN
# 3           190        35000       Sedan    Automática   Série 5       NaN
# 4           190        78453       Sedan    Automática  Classe E  Nacional
# ...         ...          ...         ...           ...       ...       ...
# 15809       116        10000    Citadino    Automática       NaN  Nacional
# 15810       200        17900  Supersport       Unknown       NaN       NaN
# 15811       190        22373    Carrinha    Automática   Série 3       NaN
# 15812       190        10000       Sedan    Automática   Série 5  Nacional
# 15813       204        33000      Cabrio    Automática  Classe C  Nacional
#
# [15814 rows x 11 columns]

# %%
data['Ano de Registo'].value_counts().sort_index().tail(30)
# Out:
# 1991      16
# 1992      29
# 1993      13
# 1994      25
# 1995      20
# 1996      34
# 1997      37
# 1998      83
# 1999     108
# 2000     160
# 2001     157
# 2002     189
# 2003     191
# 2004     223
# 2005     305
# 2006     328
# 2007     459
# 2008     622
# 2009     500
# 2010     758
# 2011     720
# 2012     568
# 2013     709
# 2014    1206
# 2015    1985
# 2016    1547
# 2017    1560
# 2018    1712
# 2019    1359
# 2020      29
# Name: Ano de Registo, dtype: int64

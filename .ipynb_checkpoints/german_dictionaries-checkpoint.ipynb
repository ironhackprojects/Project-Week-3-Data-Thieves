# %%
##lib importing
import pandas as pd

# %%
##files loading
path = "datasets/"
filename = "german.csv"
german = pd.read_csv(path + filename, index_col=0)
german
# Out:
#         price vehicleType  yearOfRegistration    gearbox  horsepower  \
# 3        1500  kleinwagen                2001    manuell      73.950
# 4        3600  kleinwagen                2008    manuell      68.034
# 6        2200      cabrio                2004    manuell     107.474
# 10       2000   limousine                2004    manuell     103.530
# 14      17999         suv                2011    manuell     187.340
# ...       ...         ...                 ...        ...         ...
# 371516   1490  kleinwagen                1998    manuell      49.300
# 371517   7900   limousine                2010    manuell     138.040
# 371524   1199      cabrio                2000  automatik      99.586
# 371525   9200         bus                1996    manuell     100.572
# 371527  28990   limousine                2013    manuell     315.520
#
#         kilometer fuelType       brand
# 3          150000   benzin  volkswagen
# 4           90000   diesel       skoda
# 6          150000   benzin     peugeot
# 10         150000   benzin       mazda
# 14          70000   diesel      nissan
# ...           ...      ...         ...
# 371516     150000   benzin  volkswagen
# 371517     150000   diesel  volkswagen
# 371524     125000   benzin       smart
# 371525     150000   diesel  volkswagen
# 371527      50000   benzin         bmw
#
# [223439 rows x 8 columns]

# %%
german = german.rename(columns={"vehicleType": "vehicle_type", "yearOfRegistration": "year", "gearbox": "transmission", "kilometer": "km", "fuelType": "fuel_type"})

# %%
set(german['vehicle_type'])
# Out:
# {'andere', 'bus', 'cabrio', 'coupe', 'kleinwagen', 'kombi', 'limousine', 'suv'}

# %%
vehicle_type_dict = {"andere" : "other", 'bus' : "van", 'cabrio' : "cabrio", 'coupe' : "coupé", 'kleinwagen' : "small_car", 'kombi' : "sports_tourism_van", 'limousine' : 'large_family_car', 'suv' : 'suv'}

# %%
german['vehicle_type'] = german['vehicle_type'].map(vehicle_type_dict)

# %%
transmission_dict = {"manuell": "manual", "automatik": "automatic"}
german['transmission'] = german['transmission'].map(transmission_dict)

german
# Out:
#         price      vehicle_type  year transmission  horsepower      km  \
# 3        1500         small_car  2001       manual      73.950  150000
# 4        3600         small_car  2008       manual      68.034   90000
# 6        2200            cabrio  2004       manual     107.474  150000
# 10       2000  large_family_car  2004       manual     103.530  150000
# 14      17999               suv  2011       manual     187.340   70000
# ...       ...               ...   ...          ...         ...     ...
# 371516   1490         small_car  1998       manual      49.300  150000
# 371517   7900  large_family_car  2010       manual     138.040  150000
# 371524   1199            cabrio  2000    automatic      99.586  125000
# 371525   9200               van  1996       manual     100.572  150000
# 371527  28990  large_family_car  2013       manual     315.520   50000
#
#        fuel_type       brand
# 3         benzin  volkswagen
# 4         diesel       skoda
# 6         benzin     peugeot
# 10        benzin       mazda
# 14        diesel      nissan
# ...          ...         ...
# 371516    benzin  volkswagen
# 371517    diesel  volkswagen
# 371524    benzin       smart
# 371525    diesel  volkswagen
# 371527    benzin         bmw
#
# [223439 rows x 8 columns]

# %%
german['horsepower'] = german['horsepower'].astype(int)

# %%
german['fuel_type'].unique()
# Out:
# array(['benzin', 'diesel', 'lpg', 'andere', 'hybrid', 'cng', 'elektro'],
#       dtype=object)

# %%
fuel_dict = {"benzin": "gas", "diesel": "diesel", "lpg": "GPL", 'andere': "other", 'hybrid': 'hybrid', 'cng': "CNG"}

# %%
german['fuel_type'] = german['fuel_type'].map(fuel_dict)

# %%
german.dtypes
# Out:
# price            int64
# vehicle_type    object
# year             int64
# transmission    object
# horsepower       int64
# km               int64
# fuel_type       object
# brand           object
# dtype: object

# %%
german.to_csv(path + "german_transl.csv")
german
# Out:
#         price      vehicle_type  year transmission  horsepower      km  \
# 3        1500         small_car  2001       manual          73  150000
# 4        3600         small_car  2008       manual          68   90000
# 6        2200            cabrio  2004       manual         107  150000
# 10       2000  large_family_car  2004       manual         103  150000
# 14      17999               suv  2011       manual         187   70000
# ...       ...               ...   ...          ...         ...     ...
# 371516   1490         small_car  1998       manual          49  150000
# 371517   7900  large_family_car  2010       manual         138  150000
# 371524   1199            cabrio  2000    automatic          99  125000
# 371525   9200               van  1996       manual         100  150000
# 371527  28990  large_family_car  2013       manual         315   50000
#
#        fuel_type       brand
# 3            gas  volkswagen
# 4         diesel       skoda
# 6            gas     peugeot
# 10           gas       mazda
# 14        diesel      nissan
# ...          ...         ...
# 371516       gas  volkswagen
# 371517    diesel  volkswagen
# 371524       gas       smart
# 371525    diesel  volkswagen
# 371527       gas         bmw
#
# [223439 rows x 8 columns]
